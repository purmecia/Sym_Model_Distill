# %%
import csv
import pandas as pd

# %% [markdown]
# # Data preprocessing (if needed)

# %%
string_name_data = 'gpt2_without_finetune_first_sentence' # change this

start = 300 # change this
end = 399 # change this

df = pd.read_csv(f'{string_name_data}.tsv', sep='\t', names = ['A', 'B'])

df = df[start: end+1] # if we want to divide the work of one output, then adjust this number

df
# Out:
#                                                      A  \
# 300          PersonX has some problems  xEffect  [GEN]
# 301         PersonX dances at the party  xReact  [GEN]
# 302     PersonX and PersonY live nearby  xReact  [GEN]
# 303  PersonX thinks of someone else's bad decision ...
# 304      PersonX finds a role model  HinderedBy  [GEN]
# ..                                                 ...
# 395           PersonX is very confident  xReact  [GEN]
# 396       PersonX just married PersonY  xIntent  [GEN]
# 397       PersonX wants to visit the zoo  xNeed  [GEN]
# 398         PersonX receives and email  xEffect  [GEN]
# 399         PersonX stops by PersonY's  xIntent  [GEN]
#
#                                                      B
# 300   xLabel [CHANGED] xLabel [CHANGED] xLabel [CHA...
# 301                                                  X
# 302                             is using a modified X3
# 303                 is too smart to tell his own story
# 304                                                NaN
# ..                                                 ...
# 395                has a great performance: http://puu
# 396   xIntent_x = Gen [2] xIntent_y = PersonX xInte...
# 397   [FADE] The game will be about playing a girl ...
# 398                                                NaN
# 399  , the  (xIntent,  [xIntent, f, g, h], xIntent)...
#
# [100 rows x 2 columns]

# %%
# declare relations
# for now we only define for these 7 relations. Relation which does not appear in this
# will be omitted. 

relations = {
    "HinderedBy": ', can be hindered by, ',
    "xNeed": " but before, PersonX needed ",
    "xWant": ", as a result, PersonX wants ",
    "xIntent": " because PersonX wanted ",
    "xReact": ", as a result, PersonX feels ",
    "xAttr": " so, PersonX is seen as ",
    "xEffect": ", as a result, PersonX ",
}

# %%
def name_PX_PY(s):
    return s.replace('PersonX', 'Alice').replace('PersonY', 'Bob')

# %%
# preferred data format (json)

"""
data = {
  phrase1: {
    "A": ...,
    "B": ...,
    "R": ...,
  }
}
"""

data = {}

for i in range(start, end+1):
  sample = df.loc[i].tolist()
  split_strings = sample[0].split(" ")
  rela_type = split_strings[-3]
  if rela_type not in relations:
    continue

  sample_ind = "phrase" + str(i)
  data[sample_ind] = {}
  data[sample_ind]['B'] = sample[1]
  data[sample_ind]['R'] = relations[rela_type]
  data[sample_ind]['A'] = " ".join(split_strings[:len(split_strings)-4])
  data[sample_ind]['label'] = 0
  data[sample_ind]['A_origin'] = sample[0]
  data[sample_ind]['B_origin'] = sample[1]

# %%
data
# Out:
# {'phrase300': {'B': 'nfusing  I was running off of the main menu   and trying the mouse to see how I was able to jump. I was able to move all over this area',
#   'R': ', as a result, PersonX ',
#   'A': 'PersonX has some problems',
#   'label': 0,
#   'A_origin': 'PersonX has some problems  xEffect  [GEN]',
#   'B_origin': 'nfusing  I was running off of the main menu   and trying the mouse to see how I was able to jump. I was able to move all over this area'},
#  'phrase301': {'B': nan,
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX dances at the party',
#   'label': 0,
#   'A_origin': 'PersonX dances at the party  xReact  [GEN]',
#   'B_origin': nan},
#  'phrase302': {'B': 'this to each xGen for X [GEN] and xAchievements  [GEN] : Add one entry to each xGen for the next xGen and',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX and PersonY live nearby',
#   'label': 0,
#   'A_origin': 'PersonX and PersonY live nearby  xReact  [GEN]',
#   'B_origin': 'this to each xGen for X [GEN] and xAchievements  [GEN] : Add one entry to each xGen for the next xGen and'},
#  'phrase303': {'B': "[GEN] I'm thinking about it xReact  [F1] I didn't think about that [F2] Why would you be so selfish? (f)",
#   'R': ', as a result, PersonX feels ',
#   'A': "PersonX thinks of someone else's bad decision",
#   'label': 0,
#   'A_origin': "PersonX thinks of someone else's bad decision  xReact  [GEN]",
#   'B_origin': "[GEN] I'm thinking about it xReact  [F1] I didn't think about that [F2] Why would you be so selfish? (f)"},
#  'phrase304': {'B': '0) ; has high character level,  : is capable of being a hero, or to be useful in a lot of situations I find it frustrating',
#   'R': ', can be hindered by, ',
#   'A': 'PersonX finds a role model',
#   'label': 0,
#   'A_origin': 'PersonX finds a role model  HinderedBy  [GEN]',
#   'B_origin': '0) ; has high character level,  : is capable of being a hero, or to be useful in a lot of situations I find it frustrating'},
#  'phrase305': {'B': 'llerGunslingerMaulerScoutHang in there, people. A big part of what we do is',
#   'R': ', as a result, PersonX ',
#   'A': 'PersonX gets more equipment',
#   'label': 0,
#   'A_origin': 'PersonX gets more equipment  xEffect  [GEN]',
#   'B_origin': 'llerGunslingerMaulerScoutHang in there, people. A big part of what we do is'},
#  'phrase306': {'B': 'React API xReact and react.base.js have a small, customizable API that makes building your own apps much easier. So lets',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX helps people',
#   'label': 0,
#   'A_origin': 'PersonX helps people  xReact  [GEN]',
#   'B_origin': 'React API xReact and react.base.js have a small, customizable API that makes building your own apps much easier. So lets'},
#  'phrase307': {'B': 'x(xGenIdx, idx) xxGenIdx(xxGenIdx) xx GenIdx(xxGenIdx) xxGenIdx',
#   'R': ', as a result, PersonX ',
#   'A': 'PersonX murders his stepfather',
#   'label': 0,
#   'A_origin': 'PersonX murders his stepfather  xEffect  [GEN]',
#   'B_origin': 'x(xGenIdx, idx) xxGenIdx(xxGenIdx) xx GenIdx(xxGenIdx) xxGenIdx'},
#  'phrase308': {'B': 't  [GEN] xIntent, Y Intent, and Z intent, so if we want to build trees, we can build our own. But that tree will be completely artificial!',
#   'R': ' because PersonX wanted ',
#   'A': 'PersonX becomes more environmentally friendly',
#   'label': 0,
#   'A_origin': 'PersonX becomes more environmentally friendly  xIntent  [GEN]',
#   'B_origin': 't  [GEN] xIntent, Y Intent, and Z intent, so if we want to build trees, we can build our own. But that tree will be completely artificial!'},
#  'phrase309': {'B': 'tedBy  [GEN] First Generation Generation Generation GenerationHintedBy  [GEN] Second Generation Generation Generation Generation Generation Generation of the same',
#   'R': ', can be hindered by, ',
#   'A': 'PersonX starts to read a book',
#   'label': 0,
#   'A_origin': 'PersonX starts to read a book  HinderedBy  [GEN]',
#   'B_origin': 'tedBy  [GEN] First Generation Generation Generation GenerationHintedBy  [GEN] Second Generation Generation Generation Generation Generation Generation of the same'},
#  'phrase310': {'B': "eeds to be able to reach Y's chest at close range. Can only take advantage of Level 20 in the area, and will lose access to the first 20%.",
#   'R': ' but before, PersonX needed ',
#   'A': 'PersonX tries to outsmart PersonY',
#   'label': 0,
#   'A_origin': 'PersonX tries to outsmart PersonY  xNeed  [GEN]',
#   'B_origin': "eeds to be able to reach Y's chest at close range. Can only take advantage of Level 20 in the area, and will lose access to the first 20%."},
#  'phrase311': {'B': 'xNeed  [GEN]PersonX gives himself up in response: x Need  [GEN][x] x Need {Chrysalis}X Needs',
#   'R': ' but before, PersonX needed ',
#   'A': 'PersonX tells PersonY he thinks the plan is rubbish',
#   'label': 0,
#   'A_origin': 'PersonX tells PersonY he thinks the plan is rubbish  xNeed  [GEN]',
#   'B_origin': 'xNeed  [GEN]PersonX gives himself up in response: x Need  [GEN][x] x Need {Chrysalis}X Needs'},
#  'phrase312': {'B': 'e any problem with the database? xReact tells PersonX about a problem with the database. xreact tells the reader to delete all of their records by their',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX asks PersonY about ...',
#   'label': 0,
#   'A_origin': 'PersonX asks PersonY about ...  xReact  [GEN]',
#   'B_origin': 'e any problem with the database? xReact tells PersonX about a problem with the database. xreact tells the reader to delete all of their records by their'},
#  'phrase313': {'B': '/u/ponycotta [LINK] xAttr : [LINK] /u/drugbear [LINK]',
#   'R': ' so, PersonX is seen as ',
#   'A': 'PersonX lies about his name',
#   'label': 0,
#   'A_origin': 'PersonX lies about his name  xAttr  [GEN]',
#   'B_origin': '/u/ponycotta [LINK] xAttr : [LINK] /u/drugbear [LINK]'},
#  'phrase314': {'B': "[GEN] : I'm talking to yourself. I just didn't like it. My mind's already busy. Haha, how much? You know I think your mind has",
#   'R': ', can be hindered by, ',
#   'A': 'PersonX tells PersonY they need to talk',
#   'label': 0,
#   'A_origin': 'PersonX tells PersonY they need to talk  HinderedBy  [GEN]',
#   'B_origin': "[GEN] : I'm talking to yourself. I just didn't like it. My mind's already busy. Haha, how much? You know I think your mind has"},
#  'phrase315': {'B': 'clusive Magic 』 / 『Sniper Gun ゼシュアルダー』 [EXP] 『Legendary Weapons 』 『Riflegun',
#   'R': ', as a result, PersonX ',
#   'A': "PersonX's father is inconsiderate",
#   'label': 0,
#   'A_origin': "PersonX's father is inconsiderate  xEffect  [GEN]",
#   'B_origin': 'clusive Magic 』 / 『Sniper Gun ゼシュアルダー』 [EXP] 『Legendary Weapons 』 『Riflegun'},
#  'phrase316': {'B': "er's character is not already in the fight, the character can escape, if the player has the right to do so after the action ends. If the character makes a",
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX becomes delighted',
#   'label': 0,
#   'A_origin': 'PersonX becomes delighted  xReact  [GEN]',
#   'B_origin': "er's character is not already in the fight, the character can escape, if the player has the right to do so after the action ends. If the character makes a"},
#  'phrase317': {'B': 'nly people who would dare to take off their trousers and their caps and all their ties and their coats and all their boots and jackets and all their jew',
#   'R': ', can be hindered by, ',
#   'A': 'PersonX is in a war',
#   'label': 0,
#   'A_origin': 'PersonX is in a war  HinderedBy  [GEN]',
#   'B_origin': 'nly people who would dare to take off their trousers and their caps and all their ties and their coats and all their boots and jackets and all their jew'},
#  'phrase318': {'B': 'e you" [Gen] says "I love you" [Gen] says "I love you" [Gen] says "I love you" (',
#   'R': ' because PersonX wanted ',
#   'A': "PersonX says 'I love you'",
#   'label': 0,
#   'A_origin': "PersonX says 'I love you'  xIntent  [GEN]",
#   'B_origin': 'e you" [Gen] says "I love you" [Gen] says "I love you" [Gen] says "I love you" ('},
#  'phrase319': {'B': 'starting a career and is looking for new jobs. xWant  and will leave for the US to join xWant  [GEN]$.xWant  [',
#   'R': ', as a result, PersonX wants ',
#   'A': 'PersonX has a financial setback',
#   'label': 0,
#   'A_origin': 'PersonX has a financial setback  xWant  [GEN]',
#   'B_origin': 'starting a career and is looking for new jobs. xWant  and will leave for the US to join xWant  [GEN]$.xWant  ['},
#  'phrase320': {'B': ']) yAttr  [GEN] XAttr ; is set to 0 for white background; will set the current size of the display. hColor',
#   'R': ' so, PersonX is seen as ',
#   'A': 'PersonX finds the right way',
#   'label': 0,
#   'A_origin': 'PersonX finds the right way  xAttr  [GEN]',
#   'B_origin': ']) yAttr  [GEN] XAttr ; is set to 0 for white background; will set the current size of the display. hColor'},
#  'phrase321': {'B': "hat you pay for, and you then create something else, and you're just like the original programmer, but with nothing for you to draw. I've been",
#   'R': ' because PersonX wanted ',
#   'A': 'PersonX is hard at work',
#   'label': 0,
#   'A_origin': 'PersonX is hard at work  xIntent  [GEN]',
#   'B_origin': "hat you pay for, and you then create something else, and you're just like the original programmer, but with nothing for you to draw. I've been"},
#  'phrase322': {'B': 'ady to make your way back to the palace to complete the mission! Go to this office to find the next stage of the mission. Now, to get to the main room',
#   'R': ', as a result, PersonX wants ',
#   'A': 'PersonX loses their coat',
#   'label': 0,
#   'A_origin': 'PersonX loses their coat  xWant  [GEN]',
#   'B_origin': 'ady to make your way back to the palace to complete the mission! Go to this office to find the next stage of the mission. Now, to get to the main room'},
#  'phrase323': {'B': '___________________ ______________________ ______________________ ______________________ BECAUSE IT IS THE WAY MY CIGAR IS DONE!!!! IT JUST TURNS TO START WITH THE',
#   'R': ', can be hindered by, ',
#   'A': 'PersonX dreams about her child',
#   'label': 0,
#   'A_origin': 'PersonX dreams about her child  HinderedBy  [GEN]',
#   'B_origin': '___________________ ______________________ ______________________ ______________________ BECAUSE IT IS THE WAY MY CIGAR IS DONE!!!! IT JUST TURNS TO START WITH THE'},
#  'phrase324': {'B': '[GEN] [X] [X]Gets 5x EXP (1 x EXP per battle) x [GEN]X Increases CP by 1 x',
#   'R': ' so, PersonX is seen as ',
#   'A': 'PersonX plans to surprise PersonY with a gift',
#   'label': 0,
#   'A_origin': 'PersonX plans to surprise PersonY with a gift  xAttr  [GEN]',
#   'B_origin': '[GEN] [X] [X]Gets 5x EXP (1 x EXP per battle) x [GEN]X Increases CP by 1 x'},
#  'phrase325': {'B': "N]With this we will see that there are two ways to initialize something that doesn't exist, the initial one and a new one. The first way is to",
#   'R': ' because PersonX wanted ',
#   'A': 'PersonX has to do something for PersonY',
#   'label': 0,
#   'A_origin': 'PersonX has to do something for PersonY  xIntent  [GEN]',
#   'B_origin': "N]With this we will see that there are two ways to initialize something that doesn't exist, the initial one and a new one. The first way is to"},
#  'phrase326': {'B': "M](x.1 is already present but is not considered an effect, so it's not considered an effect )If(",
#   'R': ', as a result, PersonX ',
#   'A': 'PersonX is unqualified',
#   'label': 0,
#   'A_origin': 'PersonX is unqualified  xEffect  [GEN]',
#   'B_origin': "M](x.1 is already present but is not considered an effect, so it's not considered an effect )If("},
#  'phrase327': {'B': "eme Combat - Tetsuya Kamiya (Person X in Tetsuya Kamiya's Shoujo manga) +2 xBoost +X - 1 x",
#   'R': ', as a result, PersonX ',
#   'A': 'PersonX beats PersonY in bowling',
#   'label': 0,
#   'A_origin': 'PersonX beats PersonY in bowling  xEffect  [GEN]',
#   'B_origin': "eme Combat - Tetsuya Kamiya (Person X in Tetsuya Kamiya's Shoujo manga) +2 xBoost +X - 1 x"},
#  'phrase328': {'B': 'eact < Person < Person, Cell. Person, xReact < Person ]. New () { } return PersonX < Person, New Person, xReact <',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX observes PersonY talking',
#   'label': 0,
#   'A_origin': 'PersonX observes PersonY talking  xReact  [GEN]',
#   'B_origin': 'eact < Person < Person, Cell. Person, xReact < Person ]. New () { } return PersonX < Person, New Person, xReact <'},
#  'phrase329': {'B': "an oatmeal biscuit t he year before he's in prison xAs he goes about his morning activities, xAs his wife notices that xThey are out going out",
#   'R': ' so, PersonX is seen as ',
#   'A': 'PersonX writes about a canoe trip',
#   'label': 0,
#   'A_origin': 'PersonX writes about a canoe trip  xAttr  [GEN]',
#   'B_origin': "an oatmeal biscuit t he year before he's in prison xAs he goes about his morning activities, xAs his wife notices that xThey are out going out"},
#  'phrase330': {'B': 'm before you make your first change. As you walk to the other side of the room, go to the wrong side of the room and get into the room. If',
#   'R': ' so, PersonX is seen as ',
#   'A': 'PersonX turns off a machine',
#   'label': 0,
#   'A_origin': 'PersonX turns off a machine  xAttr  [GEN]',
#   'B_origin': 'm before you make your first change. As you walk to the other side of the room, go to the wrong side of the room and get into the room. If'},
#  'phrase331': {'B': 'only be used while a hero is alive and has the ability to summon or summon an enemy.SavageSavage is the only hero, and only',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX spends 20 years in prison',
#   'label': 0,
#   'A_origin': 'PersonX spends 20 years in prison  xReact  [GEN]',
#   'B_origin': 'only be used while a hero is alive and has the ability to summon or summon an enemy.SavageSavage is the only hero, and only'},
#  'phrase332': {'B': 'Play : N/A! This is a pack of 1k packs worth of DLC. If you want to download more, you will need to purchase more',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX packs everything',
#   'label': 0,
#   'A_origin': 'PersonX packs everything  xReact  [GEN]',
#   'B_origin': 'Play : N/A! This is a pack of 1k packs worth of DLC. If you want to download more, you will need to purchase more'},
#  'phrase333': {'B': 'he two of them kiss  xReact  [GEN] [DYS] and we see the moon be on t xReact  [GEN]',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX looks upon the sunrise',
#   'label': 0,
#   'A_origin': 'PersonX looks upon the sunrise  xReact  [GEN]',
#   'B_origin': 'he two of them kiss  xReact  [GEN] [DYS] and we see the moon be on t xReact  [GEN]'},
#  'phrase334': {'B': 'EN], and gives it a free copy. As it changes, more languages also join the fold. With the new-feature features, one would expect that people would be more',
#   'R': ', can be hindered by, ',
#   'A': 'PersonX translates a book for PersonY',
#   'label': 0,
#   'A_origin': 'PersonX translates a book for PersonY  HinderedBy  [GEN]',
#   'B_origin': 'EN], and gives it a free copy. As it changes, more languages also join the fold. With the new-feature features, one would expect that people would be more'},
#  'phrase335': {'B': "T', { 'S', { 'L', { 'H', 1 } }, { 'L', 3 }, 'H' } } xEffect xType =",
#   'R': ', as a result, PersonX ',
#   'A': 'PersonX sends a condolence card',
#   'label': 0,
#   'A_origin': 'PersonX sends a condolence card  xEffect  [GEN]',
#   'B_origin': "T', { 'S', { 'L', { 'H', 1 } }, { 'L', 3 }, 'H' } } xEffect xType ="},
#  'phrase336': {'B': '], [_], [_] or new <> element. It creates a nested function (like the one below): - : New (React',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX breaks an object',
#   'label': 0,
#   'A_origin': 'PersonX breaks an object  xReact  [GEN]',
#   'B_origin': '], [_], [_] or new <> element. It creates a nested function (like the one below): - : New (React'},
#  'phrase337': {'B': ") 'What do you want?','what do you want?', 'what do you want?', 'what do you want?', '",
#   'R': ' so, PersonX is seen as ',
#   'A': 'PersonX offers to be a supervisor',
#   'label': 0,
#   'A_origin': 'PersonX offers to be a supervisor  xAttr  [GEN]',
#   'B_origin': ") 'What do you want?','what do you want?', 'what do you want?', 'what do you want?', '"},
#  'phrase338': {'B': 'xxt [CLOSED] xtxxt [CLOSED]: 3.6.3 [CLOSED]: 3.7.7 [CLOSED]: 3',
#   'R': ', as a result, PersonX ',
#   'A': 'PersonX writes the story of a life',
#   'label': 0,
#   'A_origin': 'PersonX writes the story of a life  xEffect  [GEN]',
#   'B_origin': 'xxt [CLOSED] xtxxt [CLOSED]: 3.6.3 [CLOSED]: 3.7.7 [CLOSED]: 3'},
#  'phrase339': {'B': 'The React-Dictionary of Supercharged (2012.pdf) http://react-dictionary.com/ - - - - - - - -',
#   'R': ', as a result, PersonX feels ',
#   'A': "PersonX reads all of PersonY's books",
#   'label': 0,
#   'A_origin': "PersonX reads all of PersonY's books  xReact  [GEN]",
#   'B_origin': 'The React-Dictionary of Supercharged (2012.pdf) http://react-dictionary.com/ - - - - - - - -'},
#  'phrase340': {'B': 'been committed [GEN][CHILDREN]Trying to find the culprit. xEffect  ~ ~ [GEN] will be unable',
#   'R': ', as a result, PersonX ',
#   'A': 'PersonX finds out about a murder',
#   'label': 0,
#   'A_origin': 'PersonX finds out about a murder  xEffect  [GEN]',
#   'B_origin': 'been committed [GEN][CHILDREN]Trying to find the culprit. xEffect  ~ ~ [GEN] will be unable'},
#  'phrase341': {'B': 'haracter" is the whole xForm. This was one of my goals to include in the text.// this function is called once this xForm changes FormData',
#   'R': ', as a result, PersonX ',
#   'A': 'PersonX and PersonY continue',
#   'label': 0,
#   'A_origin': 'PersonX and PersonY continue  xEffect  [GEN]',
#   'B_origin': 'haracter" is the whole xForm. This was one of my goals to include in the text.// this function is called once this xForm changes FormData'},
#  'phrase342': {'B': '[GEN] == 3 | xIntent > 3 || [ GEN ] == 2 | xIntent > 2 || [ GEN ] == 1 | [ GEN ] == 0 |',
#   'R': ' because PersonX wanted ',
#   'A': 'PersonX tells PersonY the secret to success',
#   'label': 0,
#   'A_origin': 'PersonX tells PersonY the secret to success  xIntent  [GEN]',
#   'B_origin': '[GEN] == 3 | xIntent > 3 || [ GEN ] == 2 | xIntent > 2 || [ GEN ] == 1 | [ GEN ] == 0 |'},
#  'phrase343': {'B': 'N] : [GEN] : [GEN] : [GEN] : [GEN] : [GEN] : [GEN] : [GEN] :',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX enjoys the house',
#   'label': 0,
#   'A_origin': 'PersonX enjoys the house  xReact  [GEN]',
#   'B_origin': 'N] : [GEN] : [GEN] : [GEN] : [GEN] : [GEN] : [GEN] : [GEN] :'},
#  'phrase344': {'B': '[GEN]. All three are featured in The Transformers Movie and The Cars Movie. xReact (Transformers: The Animated Series) is also featured',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX rides a skateboard',
#   'label': 0,
#   'A_origin': 'PersonX rides a skateboard  xReact  [GEN]',
#   'B_origin': '[GEN]. All three are featured in The Transformers Movie and The Cars Movie. xReact (Transformers: The Animated Series) is also featured'},
#  'phrase345': {'B': 'oes something to some sort of effect, they have a bit of banter here, as well. The whole point of those interviews is to talk about the whole thing, but',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX has a complex about his body',
#   'label': 0,
#   'A_origin': 'PersonX has a complex about his body  xReact  [GEN]',
#   'B_origin': 'oes something to some sort of effect, they have a bit of banter here, as well. The whole point of those interviews is to talk about the whole thing, but'},
#  'phrase346': {'B': '****** ********* [POP] [HIT] [ADF] [DIST] ********* ********* * In this chapter, our protagonist shows',
#   'R': ' because PersonX wanted ',
#   'A': 'PersonX talks to the psychiatrist',
#   'label': 0,
#   'A_origin': 'PersonX talks to the psychiatrist  xIntent  [GEN]',
#   'B_origin': '****** ********* [POP] [HIT] [ADF] [DIST] ********* ********* * In this chapter, our protagonist shows'},
#  'phrase347': {'B': 'it takes him out of the way before you can finish him xAttr  [GEN]He just looks about right, even though the other guy at',
#   'R': ' so, PersonX is seen as ',
#   'A': 'PersonX gets ready for the big game',
#   'label': 0,
#   'A_origin': 'PersonX gets ready for the big game  xAttr  [GEN]',
#   'B_origin': 'it takes him out of the way before you can finish him xAttr  [GEN]He just looks about right, even though the other guy at'},
#  'phrase348': {'B': '[GEN]7 4/9/2015 10:17:30 2-1 -1 PS416 No.8 5/9/2015',
#   'R': ', as a result, PersonX ',
#   'A': 'PersonX beats the living crap out of PersonY',
#   'label': 0,
#   'A_origin': 'PersonX beats the living crap out of PersonY  xEffect  [GEN]',
#   'B_origin': '[GEN]7 4/9/2015 10:17:30 2-1 -1 PS416 No.8 5/9/2015'},
#  'phrase349': {'B': '-empty array of a value xIntent - Returns an  xIntent x,  is a float value. If xIntent is zero, then',
#   'R': ' because PersonX wanted ',
#   'A': 'PersonX delivers',
#   'label': 0,
#   'A_origin': 'PersonX delivers  xIntent  [GEN]',
#   'B_origin': '-empty array of a value xIntent - Returns an  xIntent x,  is a float value. If xIntent is zero, then'},
#  'phrase350': {'B': 'JL][KZ][LK][LE][MAY][M',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX remembers the concert',
#   'label': 0,
#   'A_origin': 'PersonX remembers the concert  xReact  [GEN]',
#   'B_origin': 'JL][KZ][LK][LE][MAY][M'},
#  'phrase351': {'B': 'Rookies (XReact )"My apologies guys, but this game is too bad...""You guys are making a mess,',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX falls asleep in front of TV',
#   'label': 0,
#   'A_origin': 'PersonX falls asleep in front of TV  xReact  [GEN]',
#   'B_origin': 'Rookies (XReact )"My apologies guys, but this game is too bad...""You guys are making a mess,'},
#  'phrase352': {'B': 's required due to "Might Stuck" being the only game that is completely dependent on a PC.. This is required due to "Might',
#   'R': ', can be hindered by, ',
#   'A': 'PersonX learns to use a PC',
#   'label': 0,
#   'A_origin': 'PersonX learns to use a PC  HinderedBy  [GEN]',
#   'B_origin': 's required due to "Might Stuck" being the only game that is completely dependent on a PC.. This is required due to "Might'},
#  'phrase353': {'B': 's an assortment of random anime and novels that seem to have some kind of relation to those that were on The CW since its inception, most of which he is said to',
#   'R': ', can be hindered by, ',
#   'A': 'PersonX has a few hobbies',
#   'label': 0,
#   'A_origin': 'PersonX has a few hobbies  HinderedBy  [GEN]',
#   'B_origin': 's an assortment of random anime and novels that seem to have some kind of relation to those that were on The CW since its inception, most of which he is said to'},
#  'phrase354': {'B': "N] = x2 xIntent = 1 (where x2 is an integer)If the inputs don't get the appropriate values, xIntent can be",
#   'R': ' because PersonX wanted ',
#   'A': 'PersonX waits to see how the chips fall',
#   'label': 0,
#   'A_origin': 'PersonX waits to see how the chips fall  xIntent  [GEN]',
#   'B_origin': "N] = x2 xIntent = 1 (where x2 is an integer)If the inputs don't get the appropriate values, xIntent can be"},
#  'phrase355': {'B': 'xIntent xIntent xIntent xIntent xIntent xIntent xIntent xIntent xIntent xIntent x',
#   'R': ' because PersonX wanted ',
#   'A': 'PersonX moves closer',
#   'label': 0,
#   'A_origin': 'PersonX moves closer  xIntent  [GEN]',
#   'B_origin': 'xIntent xIntent xIntent xIntent xIntent xIntent xIntent xIntent xIntent xIntent x'},
#  'phrase356': {'B': 'r [Y] xAttr [XT] Y Attr [XZ] X Attr [L] xAttr [',
#   'R': ' so, PersonX is seen as ',
#   'A': 'PersonX polishes the toy',
#   'label': 0,
#   'A_origin': 'PersonX polishes the toy  xAttr  [GEN]',
#   'B_origin': 'r [Y] xAttr [XT] Y Attr [XZ] X Attr [L] xAttr ['},
#  'phrase357': {'B': '] [ID] [NAME] [X] [Y] [Z] {F1}[{F7}][{F8}][{F9}',
#   'R': ', as a result, PersonX wants ',
#   'A': 'PersonX tells PersonY to watch the clock',
#   'label': 0,
#   'A_origin': 'PersonX tells PersonY to watch the clock  xWant  [GEN]',
#   'B_origin': '] [ID] [NAME] [X] [Y] [Z] {F1}[{F7}][{F8}][{F9}'},
#  'phrase358': {'B': 'EN] ; : xIntent = xIntent + len ("+"); if (XIntent > [XIntent_MAX_NUMBER] <> X',
#   'R': ' because PersonX wanted ',
#   'A': 'PersonX and PersonY start all over again',
#   'label': 0,
#   'A_origin': 'PersonX and PersonY start all over again  xIntent  [GEN]',
#   'B_origin': 'EN] ; : xIntent = xIntent + len ("+"); if (XIntent > [XIntent_MAX_NUMBER] <> X'},
#  'phrase359': {'B': "] * [xAttr] [xAttr] * [ xAttr]I'll just leave it at that, let",
#   'R': ' so, PersonX is seen as ',
#   'A': 'PersonX went to the wrong place',
#   'label': 0,
#   'A_origin': 'PersonX went to the wrong place  xAttr  [GEN]',
#   'B_origin': "] * [xAttr] [xAttr] * [ xAttr]I'll just leave it at that, let"},
#  'phrase360': {'B': 'ISS]) * The next person will be the first individual to ever play PersonY with its own character, but the first person to make a team with the same',
#   'R': ', as a result, PersonX wants ',
#   'A': 'PersonX plans a future with PersonY',
#   'label': 0,
#   'A_origin': 'PersonX plans a future with PersonY  xWant  [GEN]',
#   'B_origin': 'ISS]) * The next person will be the first individual to ever play PersonY with its own character, but the first person to make a team with the same'},
#  'phrase361': {'B': '2/4) and has another mushroom [GR] [GR], at which point he says, "We can\'t tell if he\'s doing',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX sees the mushroom',
#   'label': 0,
#   'A_origin': 'PersonX sees the mushroom  xReact  [GEN]',
#   'B_origin': '2/4) and has another mushroom [GR] [GR], at which point he says, "We can\'t tell if he\'s doing'},
#  'phrase362': {'B': 'get a job [GEN] xIntent x (in fact, the whole thing should have been done when he was young). xIntent x (what really needs',
#   'R': ' because PersonX wanted ',
#   'A': 'PersonX dreams of meeting PersonY',
#   'label': 0,
#   'A_origin': 'PersonX dreams of meeting PersonY  xIntent  [GEN]',
#   'B_origin': 'get a job [GEN] xIntent x (in fact, the whole thing should have been done when he was young). xIntent x (what really needs'},
#  'phrase363': {'B': '[GEN] is not the same as  xIntent  xInvisible  )return xIntent == 0 && xInvisible == - 1.',
#   'R': ' because PersonX wanted ',
#   'A': 'PersonX wishes that the pain would go away',
#   'label': 0,
#   'A_origin': 'PersonX wishes that the pain would go away  xIntent  [GEN]',
#   'B_origin': '[GEN] is not the same as  xIntent  xInvisible  )return xIntent == 0 && xInvisible == - 1.'},
#  'phrase364': {'B': 'GX] xGX x/2 [SAME] [F] [N] (x-6)*[G',
#   'R': ', as a result, PersonX ',
#   'A': 'PersonX can be amusing',
#   'label': 0,
#   'A_origin': 'PersonX can be amusing  xEffect  [GEN]',
#   'B_origin': 'GX] xGX x/2 [SAME] [F] [N] (x-6)*[G'},
#  'phrase365': {'B': "') @Override public void onCreate ( Bundle savedInstanceState ) { super. onCreate ( savedInstanceState ); String person = user. getIdentifier",
#   'R': ' because PersonX wanted ',
#   'A': 'PersonX brings PersonY to her knees',
#   'label': 0,
#   'A_origin': 'PersonX brings PersonY to her knees  xIntent  [GEN]',
#   'B_origin': "') @Override public void onCreate ( Bundle savedInstanceState ) { super. onCreate ( savedInstanceState ); String person = user. getIdentifier"},
#  'phrase366': {'B': 'ere x is a natural rate. The Effect is just passed to HealthCare.gov., where is a natural rate. The Effect is just passed to HealthCare',
#   'R': ', as a result, PersonX ',
#   'A': 'PersonX gets a touch of influenza',
#   'label': 0,
#   'A_origin': 'PersonX gets a touch of influenza  xEffect  [GEN]',
#   'B_origin': 'ere x is a natural rate. The Effect is just passed to HealthCare.gov., where is a natural rate. The Effect is just passed to HealthCare'},
#  'phrase367': {'B': 'GEN] or when and to what extent he should be on an active military or paramilitary exercise.- See also this footnote in Section 7 of the Federal Trade Commission Act,',
#   'R': ', can be hindered by, ',
#   'A': 'PersonX keeps a record of his exercise',
#   'label': 0,
#   'A_origin': 'PersonX keeps a record of his exercise  HinderedBy  [GEN]',
#   'B_origin': 'GEN] or when and to what extent he should be on an active military or paramilitary exercise.- See also this footnote in Section 7 of the Federal Trade Commission Act,'},
#  'phrase368': {'B': 'when Person Y’s team gets together!ToysRan Kenpachi (ブラードシントの�',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX agrees to help PersonY’s team',
#   'label': 0,
#   'A_origin': 'PersonX agrees to help PersonY’s team  xReact  [GEN]',
#   'B_origin': 'when Person Y’s team gets together!ToysRan Kenpachi (ブラードシントの�'},
#  'phrase369': {'B': '] (where N is the maximum value of GEN and INT is the input size), and PersonY also tries to avoid telling PersonX.3.3 [def',
#   'R': ' because PersonX wanted ',
#   'A': 'PersonX tries to avoid telling PersonY',
#   'label': 0,
#   'A_origin': 'PersonX tries to avoid telling PersonY  xIntent  [GEN]',
#   'B_origin': '] (where N is the maximum value of GEN and INT is the input size), and PersonY also tries to avoid telling PersonX.3.3 [def'},
#  'phrase370': {'B': 't  [GEN] * (PersonX.Name) x [GEN].TargetX <TargetName.X> [GEN] * A new value for x_effect is added.',
#   'R': ', as a result, PersonX ',
#   'A': 'PersonX considers how to take care of PersonY',
#   'label': 0,
#   'A_origin': 'PersonX considers how to take care of PersonY  xEffect  [GEN]',
#   'B_origin': 't  [GEN] * (PersonX.Name) x [GEN].TargetX <TargetName.X> [GEN] * A new value for x_effect is added.'},
#  'phrase371': {'B': 'ou like to participate?" [GEN] "Yes." [GEN] "Yes." [GEN] "No." [GEN] "Yes." [GEN] "No',
#   'R': ', as a result, PersonX wants ',
#   'A': 'PersonX is asked about PersonY',
#   'label': 0,
#   'A_origin': 'PersonX is asked about PersonY  xWant  [GEN]',
#   'B_origin': 'ou like to participate?" [GEN] "Yes." [GEN] "Yes." [GEN] "No." [GEN] "Yes." [GEN] "No'},
#  'phrase372': {'B': 'TAN-2] [RTS] zoom in to zoom in on the next character  [RTS] / [RTS] /',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX starts to read the menu',
#   'label': 0,
#   'A_origin': 'PersonX starts to read the menu  xReact  [GEN]',
#   'B_origin': 'TAN-2] [RTS] zoom in to zoom in on the next character  [RTS] / [RTS] /'},
#  'phrase373': {'B': '0x00000001 ; (2) Set to 0x00000002 ; (3) Set to 0x000003 ; (4) Set to 0',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX burns their hand',
#   'label': 0,
#   'A_origin': 'PersonX burns their hand  xReact  [GEN]',
#   'B_origin': '0x00000001 ; (2) Set to 0x00000002 ; (3) Set to 0x000003 ; (4) Set to 0'},
#  'phrase374': {'B': 'to ignore  m xIntent. If you have only one m xIntent, the function cannot be used!To use gDirectional :',
#   'R': ' because PersonX wanted ',
#   'A': 'PersonX moves the car',
#   'label': 0,
#   'A_origin': 'PersonX moves the car  xIntent  [GEN]',
#   'B_origin': 'to ignore  m xIntent. If you have only one m xIntent, the function cannot be used!To use gDirectional :'},
#  'phrase375': {'B': 'END]',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX attends the concert',
#   'label': 0,
#   'A_origin': 'PersonX attends the concert  xReact  [GEN]',
#   'B_origin': 'END]'},
#  'phrase376': {'B': 'y  [GEN]  [TR]  [HANDERX]  (hindered by a [GEN] [TR]  (hindu ) or an   [',
#   'R': ', can be hindered by, ',
#   'A': 'PersonX makes a point of working regularly',
#   'label': 0,
#   'A_origin': 'PersonX makes a point of working regularly  HinderedBy  [GEN]',
#   'B_origin': 'y  [GEN]  [TR]  [HANDERX]  (hindered by a [GEN] [TR]  (hindu ) or an   ['},
#  'phrase377': {'B': 'and learned through it that xEffect has the power of Transmutating xEffect  [GE] (as in Transforming from human form) and that PersonY has the',
#   'R': ', as a result, PersonX ',
#   'A': 'PersonX remembers how he met PersonY',
#   'label': 0,
#   'A_origin': 'PersonX remembers how he met PersonY  xEffect  [GEN]',
#   'B_origin': 'and learned through it that xEffect has the power of Transmutating xEffect  [GE] (as in Transforming from human form) and that PersonY has the'},
#  'phrase378': {'B': 'Cuddles 2 | 5 | [YMP] Hugs & Cuddles 2 | 4 | [YMP] Fingers',
#   'R': ' because PersonX wanted ',
#   'A': 'PersonX huffs and puffs',
#   'label': 0,
#   'A_origin': 'PersonX huffs and puffs  xIntent  [GEN]',
#   'B_origin': 'Cuddles 2 | 5 | [YMP] Hugs & Cuddles 2 | 4 | [YMP] Fingers'},
#  'phrase379': {'B': 't about it, and when we see the two of us together the conversation is very intense. This leads to some kind of weird and awkward situation that only happens a handful',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX marries his love',
#   'label': 0,
#   'A_origin': 'PersonX marries his love  xReact  [GEN]',
#   'B_origin': 't about it, and when we see the two of us together the conversation is very intense. This leads to some kind of weird and awkward situation that only happens a handful'},
#  'phrase380': {'B': 'point is the "What the fuck happened to Yoda?" question. Can you explain how Yoda survived? Could you explain how the Dark Lord escaped',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX stops to check',
#   'label': 0,
#   'A_origin': 'PersonX stops to check  xReact  [GEN]',
#   'B_origin': 'point is the "What the fuck happened to Yoda?" question. Can you explain how Yoda survived? Could you explain how the Dark Lord escaped'},
#  'phrase381': {'B': 'xX | xX -> xX + xX xD xX xX | xX | xX -> xX + xX xX',
#   'R': ' because PersonX wanted ',
#   'A': 'PersonX meets his relatives',
#   'label': 0,
#   'A_origin': 'PersonX meets his relatives  xIntent  [GEN]',
#   'B_origin': 'xX | xX -> xX + xX xD xX xX | xX | xX -> xX + xX xX'},
#  'phrase382': {'B': "that means something to Yato's parents, the two don't really understand what's going on, so Yato doesn't even see things. He leaves",
#   'R': ', as a result, PersonX wants ',
#   'A': 'PersonX tries to get the baby back',
#   'label': 0,
#   'A_origin': 'PersonX tries to get the baby back  xWant  [GEN]',
#   'B_origin': "that means something to Yato's parents, the two don't really understand what's going on, so Yato doesn't even see things. He leaves"},
#  'phrase383': {'B': 'ariable.If this variable is non-negative, or if xIntent is NULL, or xValue is a string, it is put',
#   'R': ' because PersonX wanted ',
#   'A': 'PersonX will go on',
#   'label': 0,
#   'A_origin': 'PersonX will go on  xIntent  [GEN]',
#   'B_origin': 'ariable.If this variable is non-negative, or if xIntent is NULL, or xValue is a string, it is put'},
#  'phrase384': {'B': "s 'nips', he appears near a pillar in her space. This time at its back, she is not seen at all but has a massive antenna near her.",
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX begins to drink',
#   'label': 0,
#   'A_origin': 'PersonX begins to drink  xReact  [GEN]',
#   'B_origin': "s 'nips', he appears near a pillar in her space. This time at its back, she is not seen at all but has a massive antenna near her."},
#  'phrase385': {'B': 'xIntent. Put ( _, x ): fc += xIntent [xIntent.Length% 2] x = fc + f',
#   'R': ' because PersonX wanted ',
#   'A': 'PersonX refuses to let PersonY go',
#   'label': 0,
#   'A_origin': 'PersonX refuses to let PersonY go  xIntent  [GEN]',
#   'B_origin': 'xIntent. Put ( _, x ): fc += xIntent [xIntent.Length% 2] x = fc + f'},
#  'phrase386': {'B': 'GEN] A.M. XO/ XHTC was called in by the original "OZO" employee, as this is the original C3 code from last night',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX remembers what happened last night',
#   'label': 0,
#   'A_origin': 'PersonX remembers what happened last night  xReact  [GEN]',
#   'B_origin': 'GEN] A.M. XO/ XHTC was called in by the original "OZO" employee, as this is the original C3 code from last night'},
#  'phrase387': {'B': 'GEN] 3x [GEN] 1x [GEN]The "Gen" is a generalization of the word, and so does the word\'s definition.',
#   'R': ', as a result, PersonX ',
#   'A': 'PersonX spends too much time on the phone',
#   'label': 0,
#   'A_origin': 'PersonX spends too much time on the phone  xEffect  [GEN]',
#   'B_origin': 'GEN] 3x [GEN] 1x [GEN]The "Gen" is a generalization of the word, and so does the word\'s definition.'},
#  'phrase388': {'B': 'r me! [GEN] [CY] I want to see you! [CY] [CY] You are awesome! [GEN] [CY]',
#   'R': ', as a result, PersonX wants ',
#   'A': 'PersonX suffers at the beach',
#   'label': 0,
#   'A_origin': 'PersonX suffers at the beach  xWant  [GEN]',
#   'B_origin': 'r me! [GEN] [CY] I want to see you! [CY] [CY] You are awesome! [GEN] [CY]'},
#  'phrase389': {'B': 'nt xActions=10 [GEN]=2, xActions xIntent=50 [GEN]=100, xActions xInt',
#   'R': ' because PersonX wanted ',
#   'A': 'PersonX jumps from the train',
#   'label': 0,
#   'A_origin': 'PersonX jumps from the train  xIntent  [GEN]',
#   'B_origin': 'nt xActions=10 [GEN]=2, xActions xIntent=50 [GEN]=100, xActions xInt'},
#  'phrase390': {'B': '/1/2016 6:01:43] [Server thread/WARN] [deth:dekkrels:e',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX is conflicted',
#   'label': 0,
#   'A_origin': 'PersonX is conflicted  xReact  [GEN]',
#   'B_origin': '/1/2016 6:01:43] [Server thread/WARN] [deth:dekkrels:e'},
#  'phrase391': {'B': 'hoEffect xEchoEffect [GEN] - xEvTargets xEXP [EV] 0x14457775 -xEcho',
#   'R': ', as a result, PersonX ',
#   'A': 'PersonX arrives home from trip',
#   'label': 0,
#   'A_origin': 'PersonX arrives home from trip  xEffect  [GEN]',
#   'B_origin': 'hoEffect xEchoEffect [GEN] - xEvTargets xEXP [EV] 0x14457775 -xEcho'},
#  'phrase392': {'B': 'EN] [CHA] [SPE] x3 – "Just be very careful. One time, I was going on a vacation with a friend. One time, we saw',
#   'R': ', can be hindered by, ',
#   'A': 'PersonX teaches PersonY about himself',
#   'label': 0,
#   'A_origin': 'PersonX teaches PersonY about himself  HinderedBy  [GEN]',
#   'B_origin': 'EN] [CHA] [SPE] x3 – "Just be very careful. One time, I was going on a vacation with a friend. One time, we saw'},
#  'phrase393': {'B': 'l xSpeed xSpeedEffect x [ACT] xAttack xLevel xSpeed xSpeedEffect x [ACT] xAttack xLevel xSpeed xSpeedEffect x [ATT',
#   'R': ', as a result, PersonX ',
#   'A': 'PersonX has stomachache',
#   'label': 0,
#   'A_origin': 'PersonX has stomachache  xEffect  [GEN]',
#   'B_origin': 'l xSpeed xSpeedEffect x [ACT] xAttack xLevel xSpeed xSpeedEffect x [ACT] xAttack xLevel xSpeed xSpeedEffect x [ATT'},
#  'phrase394': {'B': 'e Best of the best: [MIL] = To make things worse, to make things better, [MIL] = To make things worse. XAtt',
#   'R': ' so, PersonX is seen as ',
#   'A': 'PersonX sticks to his motto',
#   'label': 0,
#   'A_origin': 'PersonX sticks to his motto  xAttr  [GEN]',
#   'B_origin': 'e Best of the best: [MIL] = To make things worse, to make things better, [MIL] = To make things worse. XAtt'},
#  'phrase395': {'B': 'be awesome :p Thanks!(4/20/2014)(4/30/2014)(5/27/2014)',
#   'R': ', as a result, PersonX feels ',
#   'A': 'PersonX is very confident',
#   'label': 0,
#   'A_origin': 'PersonX is very confident  xReact  [GEN]',
#   'B_origin': 'be awesome :p Thanks!(4/20/2014)(4/30/2014)(5/27/2014)'},
#  'phrase396': {'B': 'aracter who says he wants to become an artist, who says he wants to be a composer, who says "I\'d like a movie that will make me',
#   'R': ' because PersonX wanted ',
#   'A': 'PersonX just married PersonY',
#   'label': 0,
#   'A_origin': 'PersonX just married PersonY  xIntent  [GEN]',
#   'B_origin': 'aracter who says he wants to become an artist, who says he wants to be a composer, who says "I\'d like a movie that will make me'},
#  'phrase397': {'B': "the current date. Then he'll come to my place. [xNeed] and xNeed are the only ones who want to see him  xV [GEN",
#   'R': ' but before, PersonX needed ',
#   'A': 'PersonX wants to visit the zoo',
#   'label': 0,
#   'A_origin': 'PersonX wants to visit the zoo  xNeed  [GEN]',
#   'B_origin': "the current date. Then he'll come to my place. [xNeed] and xNeed are the only ones who want to see him  xV [GEN"},
#  'phrase398': {'B': 'eives  xAttack and XSpan xDamage <GEN] from xEffect. If xXAttack is 100% then he loses the attribute xEffect receives from  xEffect',
#   'R': ', as a result, PersonX ',
#   'A': 'PersonX receives and email',
#   'label': 0,
#   'A_origin': 'PersonX receives and email  xEffect  [GEN]',
#   'B_origin': 'eives  xAttack and XSpan xDamage <GEN] from xEffect. If xXAttack is 100% then he loses the attribute xEffect receives from  xEffect'},
#  'phrase399': {'B': "an change your mind', which tells an X to say that.PersonX stops a turn later when Person Y turns rightExit Game",
#   'R': ' because PersonX wanted ',
#   'A': "PersonX stops by PersonY's",
#   'label': 0,
#   'A_origin': "PersonX stops by PersonY's  xIntent  [GEN]",
#   'B_origin': "an change your mind', which tells an X to say that.PersonX stops a turn later when Person Y turns rightExit Game"}}

# %% [markdown]
# # Hand labeling

# %% [markdown]
# ## Handling interruption
#
# To prevent the scenario that we need to relabel from the start if the kernel is interrupted, for each phrase of the data, a label index is assigned. They are initially 0, but when we finish labeling on sentence, it will be set to 1.

# %%
# Do not rerun this unless you want to label from the start

labels = {
    "always/often": 0,
    "sometimes/likely": 0,
    "farfetched/never": 0,
    "invalid": 0,
    "too unfamiliar to judge": 0,
}

categories = ["always/often",
    "sometimes/likely",
    "farfetched/never",
    "invalid",
    "too unfamiliar to judge",
]

new_data = {
    "A": [],
    "B": [],
    "label": [],
}

# %%
# Program to assist hand-labeling of questions
# Rerun this cell if interrupted. DO NOT rerun the above cell which tracks the labeling, otherwise it will reset.

changename = False # change this for dataset 6
count = 1
for phrase in data:
  if data[phrase]['label'] == 1:
    continue
  if changename:
    print(name_PX_PY(f"Phrase {count}: " + f"\x1b[34m{data[phrase]['A']}\x1b[0m" + data[phrase]['R'] + f"\x1b[35m{data[phrase]['B']}\x1b[0m"))
  else:
    print(f"Phrase {count}: " + f"\x1b[34m{data[phrase]['A']}\x1b[0m" + data[phrase]['R'] + f"\x1b[35m{data[phrase]['B']}\x1b[0m")
  print("\x1b[47;1mHow often does the assertion hold true?\x1b[0m")
  print("0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge")
  res = input("Enter your evaluation: ")
  labels[categories[int(res)]] += 1
  data[phrase]['label'] = 1
  new_data['A'].append(data[phrase]['A_origin'])
  new_data['B'].append(data[phrase]['B_origin'])
  new_data['label'].append('yes' if int(res) < 2 else 'no')
  count += 1
# Out:
# Phrase 1: PersonX has some problems, as a result, PersonX nfusing  I was running off of the main menu   and trying the mouse to see how I was able to jump. I was able to move all over this area
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 2: PersonX dances at the party, as a result, PersonX feels nan
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 3: PersonX and PersonY live nearby, as a result, PersonX feels this to each xGen for X [GEN] and xAchievements  [GEN] : Add one entry to each xGen for the next xGen and
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 4: PersonX thinks of someone else's bad decision, as a result, PersonX feels [GEN] I'm thinking about it xReact  [F1] I didn't think about that [F2] Why would you be so selfish? (f)
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 5: PersonX finds a role model, can be hindered by, 0) ; has high character level,  : is capable of being a hero, or to be useful in a lot of situations I find it frustrating
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 6: PersonX gets more equipment, as a result, PersonX llerGunslingerMaulerScoutHang in there, people. A big part of what we do is
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 7: PersonX helps people, as a result, PersonX feels React API xReact and react.base.js have a small, customizable API that makes building your own apps much easier. So lets
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 8: PersonX murders his stepfather, as a result, PersonX x(xGenIdx, idx) xxGenIdx(xxGenIdx) xx GenIdx(xxGenIdx) xxGenIdx
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 9: PersonX becomes more environmentally friendly because PersonX wanted t  [GEN] xIntent, Y Intent, and Z intent, so if we want to build trees, we can build our own. But that tree will be completely artificial!
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 10: PersonX starts to read a book, can be hindered by, tedBy  [GEN] First Generation Generation Generation GenerationHintedBy  [GEN] Second Generation Generation Generation Generation Generation Generation of the same
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 11: PersonX tries to outsmart PersonY but before, PersonX needed eeds to be able to reach Y's chest at close range. Can only take advantage of Level 20 in the area, and will lose access to the first 20%.
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 12: PersonX tells PersonY he thinks the plan is rubbish but before, PersonX needed xNeed  [GEN]PersonX gives himself up in response: x Need  [GEN][x] x Need {Chrysalis}X Needs
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 13: PersonX asks PersonY about ..., as a result, PersonX feels e any problem with the database? xReact tells PersonX about a problem with the database. xreact tells the reader to delete all of their records by their
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 14: PersonX lies about his name so, PersonX is seen as /u/ponycotta [LINK] xAttr : [LINK] /u/drugbear [LINK]
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 15: PersonX tells PersonY they need to talk, can be hindered by, [GEN] : I'm talking to yourself. I just didn't like it. My mind's already busy. Haha, how much? You know I think your mind has
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 16: PersonX's father is inconsiderate, as a result, PersonX clusive Magic 』 / 『Sniper Gun ゼシュアルダー』 [EXP] 『Legendary Weapons 』 『Riflegun
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 17: PersonX becomes delighted, as a result, PersonX feels er's character is not already in the fight, the character can escape, if the player has the right to do so after the action ends. If the character makes a
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 18: PersonX is in a war, can be hindered by, nly people who would dare to take off their trousers and their caps and all their ties and their coats and all their boots and jackets and all their jew
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 19: PersonX says 'I love you' because PersonX wanted e you" [Gen] says "I love you" [Gen] says "I love you" [Gen] says "I love you" (
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 20: PersonX has a financial setback, as a result, PersonX wants starting a career and is looking for new jobs. xWant  and will leave for the US to join xWant  [GEN]$.xWant  [
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 21: PersonX finds the right way so, PersonX is seen as ]) yAttr  [GEN] XAttr ; is set to 0 for white background; will set the current size of the display. hColor
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 22: PersonX is hard at work because PersonX wanted hat you pay for, and you then create something else, and you're just like the original programmer, but with nothing for you to draw. I've been
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 23: PersonX loses their coat, as a result, PersonX wants ady to make your way back to the palace to complete the mission! Go to this office to find the next stage of the mission. Now, to get to the main room
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 24: PersonX dreams about her child, can be hindered by, ___________________ ______________________ ______________________ ______________________ BECAUSE IT IS THE WAY MY CIGAR IS DONE!!!! IT JUST TURNS TO START WITH THE
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 25: PersonX plans to surprise PersonY with a gift so, PersonX is seen as [GEN] [X] [X]Gets 5x EXP (1 x EXP per battle) x [GEN]X Increases CP by 1 x
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 26: PersonX has to do something for PersonY because PersonX wanted N]With this we will see that there are two ways to initialize something that doesn't exist, the initial one and a new one. The first way is to
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 27: PersonX is unqualified, as a result, PersonX M](x.1 is already present but is not considered an effect, so it's not considered an effect )If(
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 28: PersonX beats PersonY in bowling, as a result, PersonX eme Combat - Tetsuya Kamiya (Person X in Tetsuya Kamiya's Shoujo manga) +2 xBoost +X - 1 x
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 29: PersonX observes PersonY talking, as a result, PersonX feels eact < Person < Person, Cell. Person, xReact < Person ]. New () { } return PersonX < Person, New Person, xReact <
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 30: PersonX writes about a canoe trip so, PersonX is seen as an oatmeal biscuit t he year before he's in prison xAs he goes about his morning activities, xAs his wife notices that xThey are out going out
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 31: PersonX turns off a machine so, PersonX is seen as m before you make your first change. As you walk to the other side of the room, go to the wrong side of the room and get into the room. If
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 32: PersonX spends 20 years in prison, as a result, PersonX feels only be used while a hero is alive and has the ability to summon or summon an enemy.SavageSavage is the only hero, and only
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 33: PersonX packs everything, as a result, PersonX feels Play : N/A! This is a pack of 1k packs worth of DLC. If you want to download more, you will need to purchase more
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 34: PersonX looks upon the sunrise, as a result, PersonX feels he two of them kiss  xReact  [GEN] [DYS] and we see the moon be on t xReact  [GEN]
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 35: PersonX translates a book for PersonY, can be hindered by, EN], and gives it a free copy. As it changes, more languages also join the fold. With the new-feature features, one would expect that people would be more
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 36: PersonX sends a condolence card, as a result, PersonX T', { 'S', { 'L', { 'H', 1 } }, { 'L', 3 }, 'H' } } xEffect xType =
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 37: PersonX breaks an object, as a result, PersonX feels ], [_], [_] or new <> element. It creates a nested function (like the one below): - : New (React
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge
# Phrase 38: PersonX offers to be a supervisor so, PersonX is seen as ) 'What do you want?','what do you want?', 'what do you want?', 'what do you want?', '
# How often does the assertion hold true?
# 0: always/often, 1: sometimes/likely, 2: farfetched/never, 3: invalid, 4: too unfamiliar to judge

# %%
# Extract labelings

print(labels)
# Out:
# {'always/often': 28, 'sometimes/likely': 36, 'farfetched/never': 25, 'invalid': 8, 'too unfamiliar to judge': 3}

# %%
new_df = pd.DataFrame(new_data)

new_df.to_csv(f'{string_name_data}_with_label_from_{start}_to_{end}.tsv', sep = '\t')
